# %%
df <- read.csv('model_data.csv')
gps <- read.csv('data/gps.csv')
dim(df)
dim(gps)
# Out:
# [1] 112113     27
# [1] 3143    4

# %%
df <- merge(df, gps, by.x = "fullfips", by.y = "fips", all.x=TRUE)
dim(df)
# Out:
# [1] 112113     30

# %%
df
# Out:
#        fullfips X      year stfips stabb cntyfips cntyname commoditycode
# 1      1001     69733  2017 1      AL    1        Autauga  41
# 2      1001     47043  2016 1      AL    1        Autauga  21
# 3      1001     91101  2018 1      AL    1        Autauga  81
# 4      1001         1  2016 1      AL    1        Autauga  41
# 5      1001         2  2016 1      AL    1        Autauga  41
# 6      1001         3  2016 1      AL    1        Autauga  21
# 7      1001         4  2016 1      AL    1        Autauga  81
# 8      1001         5  2016 1      AL    1        Autauga  11
# 9      1001     91097  2018 1      AL    1        Autauga  21
# 10     1001     31200  2018 1      AL    1        Autauga  21
# 11     1001     31201  2018 1      AL    1        Autauga  75
# 12     1001     31202  2018 1      AL    1        Autauga  81
# 13     1001     91102  2018 1      AL    1        Autauga  11
# 14     1001     69734  2017 1      AL    1        Autauga  41
# ...
